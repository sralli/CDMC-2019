# %%
import pandas as pd
import numpy as np
import altair as alt
import json
from IPython.display import HTML
from  altair.vega import v5
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.offline as py
import plotly.tools as tls
from plotly.offline import init_notebook_mode
import plotly.graph_objs as go
import palettable
init_notebook_mode(connected=True)  
plt.style.use('ggplot')

import plotly.figure_factory as ff
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Driver functions:

# %%
##-----------------------------------------------------------
# This whole section 
vega_url = 'https://cdn.jsdelivr.net/npm/vega@' + v5.SCHEMA_VERSION
vega_lib_url = 'https://cdn.jsdelivr.net/npm/vega-lib'
vega_lite_url = 'https://cdn.jsdelivr.net/npm/vega-lite@' + alt.SCHEMA_VERSION
vega_embed_url = 'https://cdn.jsdelivr.net/npm/vega-embed@3'
noext = "?noext"

paths = {
    'vega': vega_url + noext,
    'vega-lib': vega_lib_url + noext,
    'vega-lite': vega_lite_url + noext,
    'vega-embed': vega_embed_url + noext
}

workaround = """
requirejs.config({{
    baseUrl: 'https://cdn.jsdelivr.net/npm/',
    paths: {}
}});
"""

#------------------------------------------------ Defs for future rendering
def add_autoincrement(render_func):
    # Keep track of unique <div/> IDs
    cache = {}
    def wrapped(chart, id="vega-chart", autoincrement=True):
        if autoincrement:
            if id in cache:
                counter = 1 + cache[id]
                cache[id] = counter
            else:
                cache[id] = 0
            actual_id = id if cache[id] == 0 else id + '-' + str(cache[id])
        else:
            if id not in cache:
                cache[id] = 0
            actual_id = id
        return render_func(chart, id=actual_id)
    # Cache will stay outside and 
    return wrapped
            
@add_autoincrement
def render(chart, id="vega-chart"):
    chart_str = """
    <div id="{id}"></div><script>
    require(["vega-embed"], function(vg_embed) {{
        const spec = {chart};     
        vg_embed("#{id}", spec, {{defaultStyle: true}}).catch(console.warn);
        console.log("anything?");
    }});
    console.log("really...anything?");
    </script>
    """
    return HTML(
        chart_str.format(
            id=id,
            chart=json.dumps(chart) if isinstance(chart, dict) else chart.to_json(indent=None)
        )
    )



HTML("".join((
    "<script>",
    workaround.format(json.dumps(paths)),
    "</script>")))
# Out:
# <script>
# requirejs.config({
#     baseUrl: 'https://cdn.jsdelivr.net/npm/',
#     paths: {"vega": "https://cdn.jsdelivr.net/npm/vega@v5.4.0?noext", "vega-lib": "https://cdn.jsdelivr.net/npm/vega-lib?noext", "vega-lite": "https://cdn.jsdelivr.net/npm/vega-lite@v3.4.0?noext", "vega-embed": "https://cdn.jsdelivr.net/npm/vega-embed@3?noext"}
# });
# </script>

# %%
def word_cloud(df, pixwidth=720, pixheight=450, column="index", counts="count"):
    data= [dict(name="dataset", values=df.to_dict(orient="records"))]
    wordcloud = {
        "$schema": "https://vega.github.io/schema/vega/v5.json",
        "width": pixwidth,
        "height": pixheight,
        "padding": 0,
        "title": "Hover to see number of occureances from all the sequences",
        "data": data
    }
    scale = dict(
        name="color",
        type="ordinal",
        range=["cadetblue", "royalblue", "steelblue", "navy", "teal"]
    )
    mark = {
        "type":"text",
        "from":dict(data="dataset"),
        "encode":dict(
            enter=dict(
                text=dict(field=column),
                align=dict(value="center"),
                baseline=dict(value="alphabetic"),
                fill=dict(scale="color", field=column),
                tooltip=dict(signal="datum.count + ' occurrances'")
            )
        ),
        "transform": [{
            "type": "wordcloud",
            "text": dict(field=column),
            "size": [pixwidth, pixheight],
            "font": "Helvetica Neue, Arial",
            "fontSize": dict(field="datum.{}".format(counts)),
            "fontSizeRange": [10, 60],
            "padding": 2
        }]
    }
    wordcloud["scales"] = [scale]
    wordcloud["marks"] = [mark]
    
    return wordcloud

# %%
def pie_plot(labels, values, colors, title):
    fig = {
      "data": [
        {
          "values": values,
          "labels": labels,
          "domain": {"x": [0, .48]},
          "name": "Job Type",
          "sort": False,
          "marker": {'colors': colors},
          "textinfo":"percent+label+value",
          "textfont": {'color': '#FFFFFF', 'size': 10},
          "hole": .6,
          "type": "pie"
        } ],
        "layout": {
            "title":title,
            "annotations": [
                {
                    "font": {
                        "size": 25,

                    },
                    "showarrow": False,
                    "text": ""

                }
            ]
        }
    }
    return fig


def distplot(df):
    return ff.create_distplot([df['length']], ['length'], bin_size=10).show()

# %% [markdown]
# # Basic data exploration:

# %%
df = pd.DataFrame(pd.read_csv('CDMC2019 Task2 Df.csv'))

# %%
df.columns=['todrop', 'Commands', 'malware_value']
df.drop('todrop', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                             Commands  malware_value
# 0  execve ioctl ioctl prctl gettimeofday getpid g...              2
# 1  execve ioctl ioctl time getpid time getpid soc...              2
# 2  execve ioctl ioctl prctl time getpid time getp...              2
# 3  execve ioctl ioctl time getpid time getpid soc...              2
# 4  execve ioctl ioctl prctl time getpid time getp...              2

# %% [markdown]
# Adding the length of the words in the dataframe:

# %%
df['length'] = df.Commands.apply(lambda x: len(str(x).split()))

# %%
set(df.malware_value)
# Out:
# {1, 2, 3, 4, 5}

# %%
df.describe()
# Out:
#        malware_value         length
# count    4167.000000    4167.000000
# mean        1.864171    9301.065515
# std         1.008976   17924.083490
# min         1.000000      51.000000
# 25%         1.000000     435.000000
# 50%         2.000000     543.000000
# 75%         2.000000   11651.000000
# max         5.000000  189123.000000

# %% [markdown]
# Finding the counts of occurances of all the malware_types

# %%
from palettable.colorbrewer.qualitative import Dark2_5

# %%
Dark2_5.hex_colors
# Out:
# ['#1B9E77', '#D95F02', '#7570B3', '#E7298A', '#66A61E']

# %%
value_counts = df['malware_value'].value_counts()
labels = value_counts.index.tolist()
py.iplot(pie_plot(labels, value_counts, ['#1B9E77', '#D95F02', '#7570B3', '#E7298A', '#66A61E'], "Malware Types"))
# Out:
# <div>
#
#
#             <div id="5211f3a9-00f5-42ab-a620-e5ffdf59ea40" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5211f3a9-00f5-42ab-a620-e5ffdf59ea40")) {
#                     Plotly.newPlot(
#                         '5211f3a9-00f5-42ab-a620-e5ffdf59ea40',
#                         [{"domain": {"x": [0, 0.48]}, "hole": 0.6, "labels": [2, 1, 5, 4, 3], "marker": {"colors": ["#1B9E77", "#D95F02", "#7570B3", "#E7298A", "#66A61E"]}, "name": "Job Type", "sort": false, "textfont": {"color": "#FFFFFF", "size": 10}, "textinfo": "percent+label+value", "type": "pie", "values": [2265, 1541, 287, 40, 34]}],
#                         {"annotations": [{"font": {"size": 25}, "showarrow": false, "text": ""}], "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary":  ...

# %% [markdown]
# The counts stand as follows:
# - 1: 1541 instances out of 4167
# - 2: 2265 instances out of 4167
# - 3: 34 instances out of 4167
# - 4: 40 instances out of 4167
# - 5: 287 instances out of 4167

# %% [markdown]
# From the above pie plot, we can see that the data is heavily imbalanced. Solving class imbalance could be a necessary step for getting accurate classifications.
# We could:
# - Resample the data to reduce imbalance, either upsampling minority classes of downsampling the majority ones
# - Use tensorflow smote method to create more instances for the imbalance

# %% [markdown]
# Thus, since the values are in range 1-5, let's build wordclouds for them to find some similarity in the word occurances

# %% [markdown]
# # Creating wordclouds for Classification values 1-5:

# %%
#Function for wordcloud driver:
from collections import defaultdict
def wordcloud_create(df):
    corpus = df.Commands.values.tolist()
    final = defaultdict(int) #Declaring an empty dictionary for count (Saves ram usage)
    for words in corpus:
        for word in words.split():
             final[word]+=1
                
                
    corpus = pd.Series(final) #Creating a dataframe from the final default dict
    return render(word_cloud(corpus.to_frame(name="count").reset_index(), pixheight=600, pixwidth=900))

# %% [markdown]
# ## Wordcloud for Malware_value 1

# %%
df_1 = df[df.malware_value==1]

wordcloud_create(df_1)
# Out:
#     <div id="vega-chart"></div><script>
#     require(["vega-embed"], function(vg_embed) {
#         const spec = {"$schema": "https://vega.github.io/schema/vega/v5.json", "width": 900, "height": 600, "padding": 0, "title": "Hover to see number of occureances from all the sequences", "data": [{"name": "dataset", "values": [{"index": "execve", "count": 2937}, {"index": "ioctl", "count": 28934}, {"index": "access", "count": 1483}, {"index": "geteuid", "count": 413}, {"index": "prctl", "count": 2150}, {"index": "time", "count": 754164}, {"index": "getpid", "count": 363988}, {"index": "socket", "count": 218275}, {"index": "connect", "count": 205435}, {"index": "getsockname", "count": 49978}, {"index": "open", "count": 646340}, {"index": "read", "count": 4421567}, {"index": "close", "count": 280736}, {"index": "brk", "count": 366247}, {"index": "write", "count": 7743}, {"index": "fork", "count": 9657}, {"index": "wait4", "count": 1937}, {"index": "SIGCHLD", "count": 2014}, {"index": "exit", "count": 5908}, {"index": "EXIT", "count": 8350}, {"index": "getppid", "count": 24520}, {"index": "times", "count": 3162}, {"index": "fcntl", "count": 287004}, {"index": "setsockopt", "count": 18056}, {"index": "sendto", "count": 9083794}, {"index": "recvfrom", "count": 9091549}, {"index": "_newselect", "count": 118028}, {"index": "rt_sigaction", "count": 62798}, {"index": "getsockopt", "count": 152394}, {"index": "rt_sigprocmask", "count": 76742}, {"index": "nanosleep", "count": 45644}, {"index": "set_tls", "count": 809}, {"index": "gettimeofday", "count": 163649}, {"index": "clone", "count": 2272}, {"index": "exit_group", "count": 2448}, {"index": "fstat64", "count": 6661}, {"index": "getdents", "count": 11975}, {"index": "readlink", "count": 142686}, {"index": "kill", "count": 1855}, {"index": "bind", "count": 3567}, {"index": "listen", "count": 3494}, {"index": "setsid", "count": 654}, {"index": "fcntl64", "count": 52937}, {"index": "send", "count": 43766}, {"index": "KILL", "count": 961}, {"index": "mmap2", "count": 4128}, {"index": "cacheflush", "count": 1880}, {"index": "mprotect", "count": 2910}, {"index": "munmap", "count": 341}, {"index": "geteuid32", "count": 250}, {"index": "mmap", "count": 996}, {"index": "set_thread_area", "count": 1030}, {"index": "recv", "count": 20776}, {"index": "SIGSEGV", "count": 343}, {"index": "set_tid_address", "count": 1409}, {"index": "getuid", "count": 1220}, {"index": "uname", "count": 937}, {"index": "stat64", "count": 7410}, {"index": "chdir", "count": 457}, {"index": "poll", "count": 409}, {"index": "fstat", "count": 11819}, {"index": "getdents64", "count": 30222}, {"index": "flock", "count": 56}, {"index": "unlink", "count": 215}, {"index": "getrlimit", "count": 8}, {"index": "setuid", "count": 68}, {"index": "setresuid", "count": 35}, {"index": "setuid32", "count": 17}, {"index": "setresuid32", "count": 17}, {"index": "getuid32", "count": 435}, {"index": "dup2", "count": 393}, {"index": "sigreturn", "count": 363}, {"index": "gettid", "count": 463}, {"index": "epoll_create1", "count": 24}, {"index": "pipe", "count": 155}, {"index": "epoll_ctl", "count": 96}, {"index": "writev", "count": 570}, {"index": "clock_gettime", "count": 2096}, {"index": "epoll_pwait", "count": 24}, {"index": "lstat64", "count": 76}, {"index": "chmod", "count": 22}, {"index": "tgkill", "count": 22}, {"index": "SIGTRAP", "count": 45}, {"index": "waitpid", "count": 69}, {"index": "SIGPIPE", "count": 364}, {"index": "getcwd", "count": 154}, {"index": "readv", "count": 291}, {"index": "_llseek", "count": 177}, {"index": "sendfile64", "count": 354}, {"index": "rename", "count": 60}, {"index": "shmget", "count": 29}, {"index": "stat", "count": 54054}, {"index": "prlimit64", "count": 5}, {"index": "futex", "count": 5}, {"index": "shmat", "count": 22}, {"index": "shmdt", "count": 20}, {"index": "setrlimit", "count": 7}, {"index": "umask", "count": 1}, {"index": "vfork", "count": 93}, {"index": "msgget", "count": 4}, {"index": "ugetrlimit", "count": 2}, {"index": "SIGILL", "count": 2}, {"index": "sysinfo", "count": 3}, {"ind ...
#         vg_embed("#vega-chart", spec, {defaultStyle: true}).catch(console.warn);
#         console.log("anything?");
#     });
#     console.log("really...anything?");
#     </script>

# %% [markdown]
# From the given worldcloud, we can observe that the commands have instances as follows:
# - recvfrom: 9091549 instances
# - sendto: 9083794 instances
#
# Thus, we can form a vague idea that the first malware classification must be for socket tasks which involve the malware to be focused around send and recv of data between them.

# %% [markdown]
# ## Wordcloud for Malware_value 2

# %%
df_2 = df[df.malware_value==2]

wordcloud_create(df_2)
# Out:
#     <div id="vega-chart-1"></div><script>
#     require(["vega-embed"], function(vg_embed) {
#         const spec = {"$schema": "https://vega.github.io/schema/vega/v5.json", "width": 900, "height": 600, "padding": 0, "title": "Hover to see number of occureances from all the sequences", "data": [{"name": "dataset", "values": [{"index": "execve", "count": 2326}, {"index": "ioctl", "count": 30194}, {"index": "prctl", "count": 1250}, {"index": "gettimeofday", "count": 38971}, {"index": "getpid", "count": 4593}, {"index": "fork", "count": 12539}, {"index": "wait4", "count": 2179}, {"index": "SIGCHLD", "count": 2266}, {"index": "exit", "count": 12489}, {"index": "EXIT", "count": 13344}, {"index": "chdir", "count": 2214}, {"index": "setuid32", "count": 154}, {"index": "setresuid32", "count": 154}, {"index": "rt_sigaction", "count": 45242}, {"index": "socket", "count": 1273258}, {"index": "fcntl", "count": 2312641}, {"index": "connect", "count": 1246919}, {"index": "_newselect", "count": 1253044}, {"index": "getsockopt", "count": 1241292}, {"index": "nanosleep", "count": 40454}, {"index": "close", "count": 1297081}, {"index": "time", "count": 17667}, {"index": "getsockname", "count": 1778}, {"index": "open", "count": 28323}, {"index": "read", "count": 1037420}, {"index": "setsid", "count": 1602}, {"index": "rt_sigprocmask", "count": 55315}, {"index": "write", "count": 53836}, {"index": "access", "count": 41192}, {"index": "geteuid32", "count": 16}, {"index": "setuid", "count": 310}, {"index": "setresuid", "count": 310}, {"index": "brk", "count": 2117}, {"index": "send", "count": 9922}, {"index": "recv", "count": 18917}, {"index": "unlink", "count": 296}, {"index": "getppid", "count": 478}, {"index": "times", "count": 400}, {"index": "mmap", "count": 245}, {"index": "cacheflush", "count": 585}, {"index": "readlink", "count": 213}, {"index": "mprotect", "count": 293}, {"index": "munmap", "count": 101}, {"index": "mmap2", "count": 403}, {"index": "set_tls", "count": 225}, {"index": "clone", "count": 853}, {"index": "exit_group", "count": 856}, {"index": "fcntl64", "count": 250699}, {"index": "kill", "count": 10}, {"index": "KILL", "count": 13}, {"index": "bind", "count": 17}, {"index": "listen", "count": 15}, {"index": "set_thread_area", "count": 97}, {"index": "geteuid", "count": 31}, {"index": "waitpid", "count": 69}, {"index": "SIGSEGV", "count": 10}, {"index": "getuid", "count": 55}, {"index": "rename", "count": 3}, {"index": "setsockopt", "count": 13741}, {"index": "sendto", "count": 22918}, {"index": "recvfrom", "count": 13433}, {"index": "setpgid", "count": 14}, {"index": "poll", "count": 488}, {"index": "SIGPIPE", "count": 9}, {"index": "getrlimit", "count": 27}, {"index": "setrlimit", "count": 25}, {"index": "chroot", "count": 10}, {"index": "set_tid_address", "count": 57}, {"index": "fstat64", "count": 165}, {"index": "uname", "count": 49}, {"index": "stat64", "count": 179}, {"index": "fstat", "count": 678}, {"index": "getdents64", "count": 1018}, {"index": "umask", "count": 4}, {"index": "getdents", "count": 1638}, {"index": "stat", "count": 438}, {"index": "pipe", "count": 8}, {"index": "dup2", "count": 9}, {"index": "epoll_create1", "count": 2}, {"index": "epoll_ctl", "count": 8}, {"index": "readv", "count": 8}, {"index": "clock_gettime", "count": 24}, {"index": "epoll_pwait", "count": 2}, {"index": "writev", "count": 48}, {"index": "lstat64", "count": 192}, {"index": "rmdir", "count": 40}, {"index": "sigreturn", "count": 2}, {"index": "gettid", "count": 2}, {"index": "prlimit64", "count": 2}, {"index": "futex", "count": 1}, {"index": "getuid32", "count": 3}]}], "scales": [{"name": "color", "type": "ordinal", "range": ["cadetblue", "royalblue", "steelblue", "navy", "teal"]}], "marks": [{"type": "text", "from": {"data": "dataset"}, "encode": {"enter": {"text": {"field": "index"}, "align": {"value": "center"}, "baseline": {"value": "alphabetic"}, "fill": {"scale": "color", "field": "index"}, "tooltip": {"signal": "datum.count + ' occurrances'"}}}, "transform": [{"type": "wordcloud", "text": {"field": "index"}, "size": [ ...
#         vg_embed("#vega-chart-1", spec, {defaultStyle: true}).catch(console.warn);
#         console.log("anything?");
#     });
#     console.log("really...anything?");
#     </script>

# %% [markdown]
# From the given worldcloud, we can observe that the commands have instances as follows:
# - getsockopt: 1241292 instances
# - newselect: 1253044 instances
#
# Thus, we can form a vague idea that the second malware classification must be for socket tasks which involve the creation of socket and it's underlying conncections.

# %% [markdown]
# ## Wordcloud for Malware_value 3

# %%
df_3 = df[df.malware_value==3]

wordcloud_create(df_3)
# Out:
#     <div id="vega-chart-2"></div><script>
#     require(["vega-embed"], function(vg_embed) {
#         const spec = {"$schema": "https://vega.github.io/schema/vega/v5.json", "width": 900, "height": 600, "padding": 0, "title": "Hover to see number of occureances from all the sequences", "data": [{"name": "dataset", "values": [{"index": "execve", "count": 510}, {"index": "mmap2", "count": 3872}, {"index": "cacheflush", "count": 202}, {"index": "readlink", "count": 4246}, {"index": "mprotect", "count": 2196}, {"index": "brk", "count": 1126}, {"index": "munmap", "count": 34}, {"index": "set_tls", "count": 256}, {"index": "ioctl", "count": 308}, {"index": "open", "count": 7924}, {"index": "gettimeofday", "count": 85807}, {"index": "getpid", "count": 290}, {"index": "getppid", "count": 272}, {"index": "times", "count": 34}, {"index": "read", "count": 148571}, {"index": "socket", "count": 626}, {"index": "setsockopt", "count": 532}, {"index": "connect", "count": 322}, {"index": "getsockname", "count": 102}, {"index": "close", "count": 4762}, {"index": "clone", "count": 128}, {"index": "exit_group", "count": 254}, {"index": "EXIT", "count": 272}, {"index": "setsid", "count": 34}, {"index": "rt_sigaction", "count": 3782}, {"index": "clock_gettime", "count": 170988}, {"index": "stat64", "count": 2220}, {"index": "uname", "count": 253}, {"index": "send", "count": 220}, {"index": "poll", "count": 192}, {"index": "recv", "count": 191}, {"index": "sendto", "count": 159}, {"index": "recvfrom", "count": 34}, {"index": "rmdir", "count": 68}, {"index": "unlink", "count": 97}, {"index": "fstat64", "count": 2162}, {"index": "fcntl", "count": 726}, {"index": "getdents", "count": 532}, {"index": "rt_sigprocmask", "count": 574}, {"index": "wait4", "count": 350}, {"index": "SIGCHLD", "count": 238}, {"index": "sigreturn", "count": 112}, {"index": "prctl", "count": 272}, {"index": "msgget", "count": 34}, {"index": "msgctl", "count": 68}, {"index": "mknod", "count": 34}, {"index": "bind", "count": 34}, {"index": "mkdir", "count": 34}, {"index": "_newselect", "count": 85481}, {"index": "msgrcv", "count": 85444}, {"index": "set_tid_address", "count": 476}, {"index": "fcntl64", "count": 2142}, {"index": "getuid32", "count": 112}, {"index": "flock", "count": 238}, {"index": "getsockopt", "count": 476}, {"index": "writev", "count": 170}, {"index": "mmap", "count": 72}, {"index": "time", "count": 36}, {"index": "fork", "count": 144}, {"index": "exit", "count": 18}, {"index": "fstat", "count": 276}, {"index": "getdents64", "count": 586}, {"index": "stat", "count": 1534}, {"index": "set_thread_area", "count": 252}, {"index": "getuid", "count": 126}]}], "scales": [{"name": "color", "type": "ordinal", "range": ["cadetblue", "royalblue", "steelblue", "navy", "teal"]}], "marks": [{"type": "text", "from": {"data": "dataset"}, "encode": {"enter": {"text": {"field": "index"}, "align": {"value": "center"}, "baseline": {"value": "alphabetic"}, "fill": {"scale": "color", "field": "index"}, "tooltip": {"signal": "datum.count + ' occurrances'"}}}, "transform": [{"type": "wordcloud", "text": {"field": "index"}, "size": [900, 600], "font": "Helvetica Neue, Arial", "fontSize": {"field": "datum.count"}, "fontSizeRange": [10, 60], "padding": 2}]}]};
#         vg_embed("#vega-chart-2", spec, {defaultStyle: true}).catch(console.warn);
#         console.log("anything?");
#     });
#     console.log("really...anything?");
#     </script>

# %% [markdown]
# From the given worldcloud, we can observe that the commands have instances as follows:
# - clock_gettime: 170988 instances
# - gettimeofday: 85807 instances
#
# Thus, we can form a vague idea that the third malware classification must be for  tasks which involve the malware to be focused around time based data. Also, as the number of general instances of the third malware is marginally less than the first and second, it could be considered that the instances are high for extremely less instances of the third malware.

# %% [markdown]
# ## Wordcloud for Malware_value 4

# %%
df_4 = df[df.malware_value==4]

wordcloud_create(df_4)
# Out:
#     <div id="vega-chart-3"></div><script>
#     require(["vega-embed"], function(vg_embed) {
#         const spec = {"$schema": "https://vega.github.io/schema/vega/v5.json", "width": 900, "height": 600, "padding": 0, "title": "Hover to see number of occureances from all the sequences", "data": [{"name": "dataset", "values": [{"index": "execve", "count": 580}, {"index": "ioctl", "count": 3443}, {"index": "getpid", "count": 429}, {"index": "getrlimit", "count": 7}, {"index": "setrlimit", "count": 7}, {"index": "rt_sigaction", "count": 6649}, {"index": "rt_sigprocmask", "count": 5757}, {"index": "brk", "count": 396}, {"index": "fork", "count": 429}, {"index": "exit", "count": 57}, {"index": "EXIT", "count": 556}, {"index": "time", "count": 6586}, {"index": "getppid", "count": 573}, {"index": "open", "count": 2674}, {"index": "socket", "count": 3415}, {"index": "read", "count": 3851}, {"index": "close", "count": 5769}, {"index": "connect", "count": 6253}, {"index": "send", "count": 823}, {"index": "poll", "count": 824}, {"index": "recv", "count": 830}, {"index": "nanosleep", "count": 3132}, {"index": "mmap2", "count": 1082}, {"index": "cacheflush", "count": 106}, {"index": "readlink", "count": 56}, {"index": "mprotect", "count": 657}, {"index": "munmap", "count": 29}, {"index": "set_tls", "count": 99}, {"index": "pipe", "count": 99}, {"index": "fcntl64", "count": 1052}, {"index": "vfork", "count": 39}, {"index": "mkdir", "count": 1}, {"index": "SIGCHLD", "count": 443}, {"index": "getcwd", "count": 7}, {"index": "write", "count": 163}, {"index": "clone", "count": 89}, {"index": "exit_group", "count": 499}, {"index": "dup2", "count": 390}, {"index": "set_tid_address", "count": 519}, {"index": "fstat64", "count": 565}, {"index": "prctl", "count": 519}, {"index": "getuid32", "count": 131}, {"index": "uname", "count": 231}, {"index": "stat64", "count": 1618}, {"index": "wait4", "count": 456}, {"index": "sigreturn", "count": 221}, {"index": "writev", "count": 173}, {"index": "chdir", "count": 92}, {"index": "getdents64", "count": 113}, {"index": "gettid", "count": 266}, {"index": "epoll_create1", "count": 1}, {"index": "epoll_ctl", "count": 4}, {"index": "readv", "count": 208}, {"index": "clock_gettime", "count": 8}, {"index": "bind", "count": 7}, {"index": "sendto", "count": 2}, {"index": "recvfrom", "count": 2}, {"index": "getsockname", "count": 5}, {"index": "epoll_pwait", "count": 1}, {"index": "lstat64", "count": 83}, {"index": "chmod", "count": 27}, {"index": "gettimeofday", "count": 3008}, {"index": "mmap", "count": 63}, {"index": "setsockopt", "count": 36}, {"index": "_newselect", "count": 19}, {"index": "fcntl", "count": 42}, {"index": "access", "count": 55}, {"index": "flock", "count": 5}, {"index": "listen", "count": 6}, {"index": "getuid", "count": 610}, {"index": "set_thread_area", "count": 427}, {"index": "geteuid", "count": 75}, {"index": "_llseek", "count": 92}, {"index": "sendfile64", "count": 294}, {"index": "rename", "count": 30}, {"index": "unlink", "count": 30}, {"index": "utimensat", "count": 30}, {"index": "waitpid", "count": 70}, {"index": "pipe2", "count": 2}, {"index": "stat", "count": 400}, {"index": "geteuid32", "count": 15}, {"index": "times", "count": 1}, {"index": "fstat", "count": 28}]}], "scales": [{"name": "color", "type": "ordinal", "range": ["cadetblue", "royalblue", "steelblue", "navy", "teal"]}], "marks": [{"type": "text", "from": {"data": "dataset"}, "encode": {"enter": {"text": {"field": "index"}, "align": {"value": "center"}, "baseline": {"value": "alphabetic"}, "fill": {"scale": "color", "field": "index"}, "tooltip": {"signal": "datum.count + ' occurrances'"}}}, "transform": [{"type": "wordcloud", "text": {"field": "index"}, "size": [900, 600], "font": "Helvetica Neue, Arial", "fontSize": {"field": "datum.count"}, "fontSizeRange": [10, 60], "padding": 2}]}]};
#         vg_embed("#vega-chart-3", spec, {defaultStyle: true}).catch(console.warn);
#         console.log("anything?");
#     });
#     console.log("really...anything?");
#     </script>

# %% [markdown]
# From the given worldcloud, we can observe that the commands have instances as follows:
# - rt_sigaction: 6649 instances
# - rt_sigprocmask: 5757 instances
#
# Thus, we can form a vague idea that the fourth malware classification must generally be focused for masking the calling threads or actions on such threads. The number of instances are in range with the overall number of occurances for the fourth malware in the data.

# %% [markdown]
# ## Wordcloud for Malware_value 5

# %%
df_5 = df[df.malware_value==5]

wordcloud_create(df_5)
# Out:
#     <div id="vega-chart-4"></div><script>
#     require(["vega-embed"], function(vg_embed) {
#         const spec = {"$schema": "https://vega.github.io/schema/vega/v5.json", "width": 900, "height": 600, "padding": 0, "title": "Hover to see number of occureances from all the sequences", "data": [{"name": "dataset", "values": [{"index": "execve", "count": 3851}, {"index": "uname", "count": 2220}, {"index": "brk", "count": 2646}, {"index": "set_tls", "count": 3488}, {"index": "set_tid_address", "count": 3851}, {"index": "set_robust_list", "count": 985}, {"index": "futex", "count": 516}, {"index": "rt_sigaction", "count": 38525}, {"index": "rt_sigprocmask", "count": 37895}, {"index": "ugetrlimit", "count": 254}, {"index": "readlink", "count": 579}, {"index": "getcwd", "count": 287}, {"index": "clone", "count": 2511}, {"index": "wait4", "count": 1648}, {"index": "SIGCHLD", "count": 1813}, {"index": "exit_group", "count": 2009}, {"index": "EXIT", "count": 2009}, {"index": "open", "count": 108164}, {"index": "fcntl64", "count": 4868}, {"index": "fstat64", "count": 18785}, {"index": "read", "count": 102371}, {"index": "mmap2", "count": 23297}, {"index": "close", "count": 164358}, {"index": "mprotect", "count": 7622}, {"index": "prctl", "count": 3564}, {"index": "getuid32", "count": 3234}, {"index": "getpid", "count": 1813}, {"index": "getppid", "count": 1813}, {"index": "stat64", "count": 13088}, {"index": "clock_gettime", "count": 861}, {"index": "ioctl", "count": 11897}, {"index": "fchmod", "count": 861}, {"index": "fchown32", "count": 762}, {"index": "readv", "count": 1722}, {"index": "writev", "count": 1047}, {"index": "rename", "count": 861}, {"index": "write", "count": 769}, {"index": "setsid", "count": 196}, {"index": "socket", "count": 5625}, {"index": "connect", "count": 5424}, {"index": "_newselect", "count": 5415}, {"index": "getsockopt", "count": 5221}, {"index": "nanosleep", "count": 18418}, {"index": "lseek", "count": 75814}, {"index": "gettimeofday", "count": 11177}, {"index": "munmap", "count": 15474}, {"index": "send", "count": 3608}, {"index": "set_thread_area", "count": 363}, {"index": "getrlimit", "count": 33}, {"index": "waitpid", "count": 165}, {"index": "SIGSEGV", "count": 91}, {"index": "KILL", "count": 91}, {"index": "getuid", "count": 330}, {"index": "fchown", "count": 99}, {"index": "cacheflush", "count": 441}, {"index": "dup2", "count": 620}, {"index": "lstat64", "count": 186}, {"index": "unlink", "count": 62}]}], "scales": [{"name": "color", "type": "ordinal", "range": ["cadetblue", "royalblue", "steelblue", "navy", "teal"]}], "marks": [{"type": "text", "from": {"data": "dataset"}, "encode": {"enter": {"text": {"field": "index"}, "align": {"value": "center"}, "baseline": {"value": "alphabetic"}, "fill": {"scale": "color", "field": "index"}, "tooltip": {"signal": "datum.count + ' occurrances'"}}}, "transform": [{"type": "wordcloud", "text": {"field": "index"}, "size": [900, 600], "font": "Helvetica Neue, Arial", "fontSize": {"field": "datum.count"}, "fontSizeRange": [10, 60], "padding": 2}]}]};
#         vg_embed("#vega-chart-4", spec, {defaultStyle: true}).catch(console.warn);
#         console.log("anything?");
#     });
#     console.log("really...anything?");
#     </script>

# %% [markdown]
# From the given worldcloud, we can observe that the commands have instances as follows:
# - close: 164358 instances
# - open: 108164 instances
#
# Thus, we can form a vague idea that the fifth malware classification must be for socket tasks which involve the malware to be focused around the opening and closing of sockets/files, with secondary processes around time of day and masks for the threads.

# %% [markdown]
# ### To get an even more extensive idea over the wordclouds, plotting the distribution plot for the data based on length of words:

# %% [markdown]
# ### Malware: 1

# %%
df_1 = df[df.malware_value==1]
distplot(df_1)
# Out:
# <div>
#
#
#             <div id="64982683-9b66-4de9-9e31-484d2fc7a46c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("64982683-9b66-4de9-9e31-484d2fc7a46c")) {
#                     Plotly.newPlot(
#                         '64982683-9b66-4de9-9e31-484d2fc7a46c',
#                         [{"autobinx": false, "histnorm": "probability density", "legendgroup": "length", "marker": {"color": "rgb(31, 119, 180)"},